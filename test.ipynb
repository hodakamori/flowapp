# %%
from ydata_profiling import ProfileReport

# %%
import pandas as pd

df = pd.read_csv("demo/delaney.csv")
profile = ProfileReport(df, title="Profiling Report")

# %%
table_items = [
    "n",
    "n_var",
    "n_cells_missing",
    "n_vars_with_missing",
    "n_vars_all_missing",
    "types",
    "n_duplicates",
]
table_view = {}

for key in data["table"].keys():
    if key in table_items:
        table_view[key] = data["table"][key]
table_view
# Out:
# {'n': 1128,
#  'n_var': 3,
#  'n_cells_missing': 0,
#  'n_vars_with_missing': 0,
#  'n_vars_all_missing': 0,
#  'types': {'Text': 2, 'Numeric': 1},
#  'n_duplicates': 0}

# %%
import json

data = json.loads(profile.to_json())

str_items = [
    "n_distinct",
    "n_missing",
    "count",
    "max_length",
    "median_length",
    "mean_length",
    "min_length",
]

number_items = [
    "n_distinct",
    "n_missing",
    "count",
    "n_negative",
    "mean",
    "std",
    "variance",
    "min",
    "max",
]


for key in data["variables"].keys():
    print(key)
# Out:
# name
# smiles
# logS

# %%
profile
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-12-29 06:02:12.110812&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
